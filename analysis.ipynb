# %%
#installing packages
# !pip install pandas
# !pip install matplotlib.pyplot
# !pip install seaborn
# !pip install numpy
# Out:
# ...
#    ---------------------------------------- 0.0/11.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.5 MB ? eta -:--:--
#     --------------------------------------- 0.3/11.5 MB ? eta -:--:--
#     --------------------------------------- 0.3/11.5 MB ? eta -:--:--
#     --------------------------------------- 0.3/11.5 MB ? eta -:--:--
#     --------------------------------------- 0.3/11.5 MB ? eta -:--:--
#    - -------------------------------------- 0.5/11.5 MB 256.3 kB/s eta 0:00:43
#    - -------------------------------------- 0.5/11.5 MB 256.3 kB/s eta 0:00:43
#    - -------------------------------------- 0.5/11.5 MB 256.3 kB/s eta 0:00:43
#    -- ------------------------------------- 0.8/11.5 MB 346.5 kB/s eta 0:00:31
# ...

# %%
#importation of packages
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
#loading the data
histo = pd.read_csv('historical_energy_data.csv')
inf = pd.read_csv('infrastructure_data.csv')
market = pd.read_csv('market_data.csv')
reg = pd.read_csv('regulatory_data.csv')

# %%
histo.head()
# Out:
#     Date/Time Location/Region Energy Source  Energy Demand  \
# 0  01/01/2012        Region A  Fossil Fuels          24016
# 1  02/01/2012        Region C  Fossil Fuels          56200
# 2  03/01/2012        Region A    Renewables          81268
# 3  04/01/2012        Region C  Fossil Fuels          61287
# 4  05/01/2012        Region B  Fossil Fuels          93447
#
#    Energy Consumption (kWh)  Energy Price  Operational Costs  \
# 0                     21848      0.131630        1564.239198
# 1                     34796      0.160969        3837.295411
# 2                     36244      0.155890        4418.260676
# 3                     19955      0.130128        3743.417970
# 4                     13788      0.151835        1071.513936
#
#    Energy Production (kWh)
# 0                    31604
# 1                    11734
# 2                    31523
# 3                    21205
# 4                    19548

# %%
inf.head()
# Out:
#     Date/Time Infrastructure Status Maintenance Activities  \
# 0  01/01/2012                  Poor                Repairs
# 1  02/01/2012                  Poor               Upgrades
# 2  03/01/2012                  Fair               Upgrades
# 3  04/01/2012                  Poor                Repairs
# 4  05/01/2012                  Poor                Repairs
#
#   Technology Limitations
# 0                   High
# 1                   High
# 2                   High
# 3                   High
# 4                   High

# %%
market.head()
# Out:
#     Date/Time  Market Price Competitor Data Market Trends  Market Demand
# 0  2012-01-01      0.167891            High        Upward          13518
# 1  2012-01-02      0.151762          Medium        Upward           2115
# 2  2012-01-03      0.241443            High        Stable          22353
# 3  2012-01-04      0.071104             Low      Downward          25482
# 4  2012-01-05      0.107281            High        Stable          20264

# %%
reg.head()
# Out:
#     Date/Time Regulatory Changes Compliance Status  Compliance Costs
# 0  2012-01-01     New Regulation         Compliant       3281.685306
# 1  2012-01-02          Amendment     Non-compliant       2037.272281
# 2  2012-01-03          Amendment     Non-compliant        629.891778
# 3  2012-01-04     New Regulation     Non-compliant       2277.898351
# 4  2012-01-05          Amendment     Non-compliant       4687.163688

# %% [markdown]
# ##Understanding the structure of the datasets

# %%
histo.info()
histo.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Date/Time                 1000 non-null   object
#  1   Location/Region           1000 non-null   object
#  2   Energy Source             1000 non-null   object
#  3   Energy Demand             1000 non-null   int64
#  4   Energy Consumption (kWh)  1000 non-null   int64
#  5   Energy Price              1000 non-null   float64
#  6   Operational Costs         1000 non-null   float64
#  7   Energy Production (kWh)   1000 non-null   int64
# dtypes: float64(2), int64(3), object(3)
# memory usage: 62.6+ KB
#        Energy Demand  Energy Consumption (kWh)  Energy Price  \
# count    1000.000000               1000.000000   1000.000000
# mean    49336.335000              24249.533000      0.126752
# std     28215.243714              14092.904681      0.042857
# ...

# %%
inf.info()
inf.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 4 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Date/Time               1000 non-null   object
#  1   Infrastructure Status   1000 non-null   object
#  2   Maintenance Activities  1000 non-null   object
#  3   Technology Limitations  987 non-null    object
# dtypes: object(4)
# memory usage: 31.4+ KB
#          Date/Time Infrastructure Status Maintenance Activities  \
# count         1000                  1000                   1000
# unique        1000                     3                      3
# top     01/01/2012                  Poor    Routine Maintenance
# freq             1                   641                    360
#
#        Technology Limitations
# count                     987
# unique                      3
# top                      High
# freq                      776

# %%
market.info()
market.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Date/Time        1000 non-null   object
#  1   Market Price     1000 non-null   float64
#  2   Competitor Data  1000 non-null   object
#  3   Market Trends    1000 non-null   object
#  4   Market Demand    1000 non-null   int64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 39.2+ KB
#        Market Price  Market Demand
# count   1000.000000    1000.000000
# mean       0.139154   25392.807000
# std        0.063492   13980.103619
# min        0.030053     836.000000
# 25%        0.084488   13515.250000
# 50%        0.138719   24910.500000
# 75%        0.192279   37102.750000
# max        0.249960   49941.000000

# %%
reg.info()
reg.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 4 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Date/Time           1000 non-null   object
#  1   Regulatory Changes  1000 non-null   object
#  2   Compliance Status   1000 non-null   object
#  3   Compliance Costs    1000 non-null   float64
# dtypes: float64(1), object(3)
# memory usage: 31.4+ KB
#        Compliance Costs
# count       1000.000000
# mean        2841.451262
# std         1276.101688
# min          503.841638
# 25%         1778.330823
# 50%         2906.980088
# 75%         3892.981360
# max         4987.232664

# %% [raw]
# Data Cleaning

# %%
histo.head()
# Out:
#     Date/Time Location/Region Energy Source  Energy Demand  \
# 0  01/01/2012        Region A  Fossil Fuels          24016
# 1  02/01/2012        Region C  Fossil Fuels          56200
# 2  03/01/2012        Region A    Renewables          81268
# 3  04/01/2012        Region C  Fossil Fuels          61287
# 4  05/01/2012        Region B  Fossil Fuels          93447
#
#    Energy Consumption (kWh)  Energy Price  Operational Costs  \
# 0                     21848      0.131630        1564.239198
# 1                     34796      0.160969        3837.295411
# 2                     36244      0.155890        4418.260676
# 3                     19955      0.130128        3743.417970
# 4                     13788      0.151835        1071.513936
#
#    Energy Production (kWh)
# 0                    31604
# 1                    11734
# 2                    31523
# 3                    21205
# 4                    19548

# %%
inf.head()
# Out:
#     Date/Time Infrastructure Status Maintenance Activities  \
# 0  01/01/2012                  Poor                Repairs
# 1  02/01/2012                  Poor               Upgrades
# 2  03/01/2012                  Fair               Upgrades
# 3  04/01/2012                  Poor                Repairs
# 4  05/01/2012                  Poor                Repairs
#
#   Technology Limitations
# 0                   High
# 1                   High
# 2                   High
# 3                   High
# 4                   High

# %%
market.head()
# Out:
#     Date/Time  Market Price Competitor Data Market Trends  Market Demand
# 0  2012-01-01      0.167891            High        Upward          13518
# 1  2012-01-02      0.151762          Medium        Upward           2115
# 2  2012-01-03      0.241443            High        Stable          22353
# 3  2012-01-04      0.071104             Low      Downward          25482
# 4  2012-01-05      0.107281            High        Stable          20264

# %% [raw]
# reg.head()

# %%
date_format = "%d/%m/%Y"
histo['Date/Time'] = pd.to_datetime(histo['Date/Time'], format=date_format)

new_date_format = "%Y-%m-%d"

histo['Date/Time']= pd.to_datetime(histo['Date/Time'], format=new_date_format)

# %%
histo.head(1)
# Out:
#    Date/Time Location/Region Energy Source  Energy Demand  \
# 0 2012-01-01        Region A  Fossil Fuels          24016
#
#    Energy Consumption (kWh)  Energy Price  Operational Costs  \
# 0                     21848       0.13163        1564.239198
#
#    Energy Production (kWh)
# 0                    31604

# %%
date_format = "%d/%m/%Y"
inf['Date/Time'] = pd.to_datetime(inf['Date/Time'], format=date_format)

new_date_format = "%Y-%m-%d"

inf['Date/Time']= pd.to_datetime(inf['Date/Time'], format=new_date_format)

# %%
inf.head(1)
# Out:
#    Date/Time Infrastructure Status Maintenance Activities  \
# 0 2012-01-01                  Poor                Repairs
#
#   Technology Limitations
# 0                   High

# %%
new_date_format = "%Y-%m-%d"

market['Date/Time']= pd.to_datetime(market['Date/Time'], format=new_date_format)

# %%
market.head()
# Out:
#    Date/Time  Market Price Competitor Data Market Trends  Market Demand
# 0 2012-01-01      0.167891            High        Upward          13518
# 1 2012-01-02      0.151762          Medium        Upward           2115
# 2 2012-01-03      0.241443            High        Stable          22353
# 3 2012-01-04      0.071104             Low      Downward          25482
# 4 2012-01-05      0.107281            High        Stable          20264

# %%
new_date_format = "%Y-%m-%d"

reg['Date/Time']= pd.to_datetime(reg['Date/Time'], format=new_date_format)

# %%
reg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 4 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Date/Time           1000 non-null   datetime64[ns]
#  1   Regulatory Changes  1000 non-null   object
#  2   Compliance Status   1000 non-null   object
#  3   Compliance Costs    1000 non-null   float64
# dtypes: datetime64[ns](1), float64(1), object(2)
# memory usage: 31.4+ KB

# %% [raw]
# Exploratory Data Analysis(Categorical column)

# %%
#Specifically I will examine:
#Location/Region and energy source from historical_energy_data
#infrastructure status, maintenance activties, and technology limitations from infrastructure
#Competitor data and market trnds from market data
#regulatory changes and compliance from regulatory data

# %%
#Steps
#1. grouping all datasets as dataset

datasets = {"histo":histo,
    "inf":inf,
    "market":market,
    "reg":reg
}

#2. extracting unique values and their counts for categorical columns

categorical_columns= {
    "histo":["Location/Region", "Energy Source"],
    "inf":["Infrastructure Status", "Maintenance Activities", "Technology Limitations"],
    "market":["Competitor Data", "Market Trends"],
    "reg":["Regulatory Changes", "Compliance Status"]
}

categorical_values_count ={}
for dataset, columns in categorical_columns.items():
    for column in columns:
        categorical_values_count[(dataset, column)] = datasets[dataset][column].value_counts()

# %%
# !pip install matplotlib
import matplotlib.pyplot as plt

# %%
#visualizing
#calculate the number of rows and columns for the subplots

num_rows = (len(categorical_values_count) + 1) // 2
num_cols = 2

#create a grid of the subplots

fig, axes = plt.subplots(num_rows, num_cols, figsize = (12, 12))

#flatten the axes for easier indexing
axes = axes.flatten()

#iterate through categorical columns and plots them in subplots
for i, ((dataset, column), counts) in enumerate (categorical_values_count.items()):
    ax = axes[i]
    sns.barplot(x=counts.values, y=counts.index, ax=ax)
    ax.set_title("Value Counts for (dataset) - {column}")
    ax.set_xlabel("Counts")
    #ax.set_ylabels(column)

#hide any remaining empty subplots
for i in range(len(categorical_values_count), num_rows * num_cols):
    fig.delaxes(axes[i])

#adjust
plt.tight_layout()

plt.show()

# %% [markdown]
# EDA ( Energy Demand, Production, and Consumption over Time)

# %%
sns.lineplot(data=monthly_data, x=monthly_data.astype(str), y= 'Energy Consumption (kwh)', label='Energy Production', color='black', linestyle='-',linewidth='1.5', cl=None)

# %%
#Extract the month and year from 'Date/Time' column

histo['Year'] = histo["Date/Time"].dt.year
histo['Month'] = histo["Date/Time"].dt.month

#create a new column

histo ['Year-Month'] = histo["Date/Time"].dt.to_period('M')

#histo['Year-Month'] = pd.to_numeric(histo['Year-Month'], errors='coerce')

#new_date_format = "%Y-%m"

#histo['Year-Month']= pd.to_datetime(histo['Year-Month'], format=new_date_format)

# %%
#aggregating data on monthly basis
monthly_data = histo.groupby('Year-Month').mean(numeric_only=True)

# %%
print(monthly_data)
#histo.head()
# Out:
#             Energy Demand  Energy Consumption (kWh)  Energy Price  \
# Year-Month
# 2012-01      51746.612903              28030.741935      0.135257
# 2012-02      58542.068966              22298.310345      0.131823
# 2012-03      51976.903226              25060.096774      0.129830
# 2012-04      45590.000000              28423.733333      0.133459
# 2012-05      52512.258065              22419.709677      0.135185
# 2012-06      47582.700000              27110.133333      0.124403
# 2012-07      51981.612903              26462.903226      0.118212
# 2012-08      55464.225806              29452.677419      0.121871
# 2012-09      42747.233333              20565.800000      0.124142
# 2012-10      59874.935484              25714.612903      0.123240
# 2012-11      48470.366667              24521.466667      0.132305
# 2012-12      46869.451613              22399.516129      0.121623
# 2013-01      50975.612903              21885.064516      0.117536
# ...

# %%
#setting figsize
plt.figure(figsize=(15,6))

#plot

sns.lineplot(data=monthly_data, x=monthly_data.index.astype(str), y= 'Energy Production (kWh)', label='Energy Production', color='green', linestyle='-',linewidth='1.5')
sns.lineplot(data=monthly_data, x=monthly_data.index.astype(str), y= 'Energy Consumption (kWh)', label='Energy Consumption', color='black', linestyle='-',linewidth='1.5')
sns.lineplot(data=monthly_data, x=monthly_data.index.astype(str), y= 'Energy Demand', label='Energy Demand', color='blue', linestyle='-',linewidth='1.5')

#setting title and labels

plt.title('Monthly Aggregate of Energy Production, Consumption, and demand Over Time')
plt.xlabel('Date')
plt.ylabel('kwh')
plt.legend(loc="upper left", bbox_to_anchor=(1, 1))
plt.grid(True, which='both', linestyle='--', linewidth= 0.5)

#label set up

labels = monthly_data.index.astype(str)
n= 6
plt.xticks(labels[::n], rotation = 360)

plt.tight_layout()
plt.subplots_adjust(hspace=0.5)

plt.show()

# %%
histo.head()
# Out:
#    Date/Time Location/Region Energy Source  Energy Demand  \
# 0 2012-01-01        Region A  Fossil Fuels          24016
# 1 2012-01-02        Region C  Fossil Fuels          56200
# 2 2012-01-03        Region A    Renewables          81268
# 3 2012-01-04        Region C  Fossil Fuels          61287
# 4 2012-01-05        Region B  Fossil Fuels          93447
#
#    Energy Consumption (kWh)  Energy Price  Operational Costs  \
# 0                     21848      0.131630        1564.239198
# 1                     34796      0.160969        3837.295411
# 2                     36244      0.155890        4418.260676
# 3                     19955      0.130128        3743.417970
# 4                     13788      0.151835        1071.513936
#
#    Energy Production (kWh)  Year  Month Year-Month
# 0                    31604  2012      1    2012-01
# 1                    11734  2012      1    2012-01
# 2                    31523  2012      1    2012-01
# ...

# %%
histo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 11 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Date/Time                 1000 non-null   datetime64[ns]
#  1   Location/Region           1000 non-null   object
#  2   Energy Source             1000 non-null   object
#  3   Energy Demand             1000 non-null   int64
#  4   Energy Consumption (kWh)  1000 non-null   int64
#  5   Energy Price              1000 non-null   float64
#  6   Operational Costs         1000 non-null   float64
#  7   Energy Production (kWh)   1000 non-null   int64
#  8   Year                      1000 non-null   int32
#  9   Month                     1000 non-null   int32
#  10  Year-Month                1000 non-null   datetime64[ns]
# dtypes: datetime64[ns](2), float64(2), int32(2), int64(3), object(2)
# memory usage: 78.3+ KB

# %% [markdown]
# EDA 2 (Market Price and Energy Price Over Time)

# %%
#Merging historical data and market data on date/time

merged = pd.merge(histo, market, on = "Date/Time")

#setting 'date/time as the index of the dataframe for agg
merged['Year'] = merged['Date/Time'].dt.year
merged['Month'] = merged['Date/Time'].dt.month

#aggregate data on a monthly basis
monthly_merged = merged.groupby(['Year', 'Month']).mean(numeric_only=True)

#create new column for plotting
#monthly_merged['Year-Month'] = monthly_merged.index.get_level_values(0).astype(str)= '-' = monthly_merged.index.get_level_values(1).astype(str)

# %%
#create new column for plotting
monthly_merged['Year-Month'] = monthly_merged.index.get_level_values(0).astype(str)+ '-' + monthly_merged.index.get_level_values(1).astype(str)

# %%
#visualizing

plt.figure(figsize=(15, 8))

sns.lineplot(data=monthly_merged, x='Year-Month', y='Market Price', label='Market Price', color="blue", linestyle='-', linewidth= 1.5)
sns.lineplot(data=monthly_merged, x='Year-Month', y='Energy Price', label='Energy Price', color="yellow", linestyle='-', linewidth= 1.5)

plt.title('Monthly Aggregate of Market Price and Energy Price Over Time')
plt.xlabel('Date')
plt.ylabel('kwh')
plt.legend(loc="upper left", bbox_to_anchor=(1, 1))
plt.grid(True, which='both', linestyle='--', linewidth= 0.5)

labels = monthly_merged['Year-Month'].tolist()
n = 4
plt.xticks(labels[::n], rotation=360)
plt.tight_layout()

plt.show()

# %% [markdown]
# EDA 4 (Demand Correlation with Energy Price)

# %%
correlation_energy_price = merged['Energy Demand'].corr(merged['Energy Price'])
correlation_market_price = merged['Market Demand'].corr(merged['Market Price'])

# %%
correlation_energy_price
# Out:
# np.float64(-0.00536184076850342)

# %%
correlation_market_price
# Out:
# np.float64(0.02980230214828851)

# %% [markdown]
# EDA 5 (Infrastructure Status and Tech Limitations)

# %%
#setting fig and axes
fig, axes = plt.subplots(1,2, figsize=(15, 8))

#plotting the frequency of infrastructure status
sns.countplot(data=inf, x='Infrastructure Status', ax=axes[0], order=['Good', 'Fair', 'Poor'], palette='viridis')
axes[0].set_title('Frequency of Infrastructure Status')
axes[0].set_xlabel('Infrastructure Status')
axes[0].set_ylabel('count')

#plotting for technology limitation
sns.countplot(data=inf, x='Technology Limitations', ax=axes[1], palette='viridis')
axes[1].set_title('Frequency of Technology Limitations')
axes[1].set_xlabel('Technology Limitations')
axes[1].set_ylabel('count')

plt.tight_layout()
plt.show()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_3592\3953531027.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=inf, x='Infrastructure Status', ax=axes[0], order=['Good', 'Fair', 'Poor'], palette='viridis')
# C:\Users\User\AppData\Local\Temp\ipykernel_3592\3953531027.py:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=inf, x='Technology Limitations', ax=axes[1], palette='viridis')

# %%
#Relationship between infrasture status and tech limitations

cross= pd.crosstab(inf['Infrastructure Status'], inf['Technology Limitations'])

# %%
#creating a heatmap to show relationships

plt.figure(figsize=(10,4))

sns.heatmap(cross, annot = True, cmap= "viridis")
plt.title('Infrastructure Status vs. Technology Limitations')
plt.xlabel('Technology Limitations')
plt.ylabel('Infrastructure Status')

plt.tight_layout()
plt.show()

# %%
#Correlation between poor infrastructure status and high tech limitations in the energy production
inf['Poor_Infrastructure'] = inf['Infrastructure Status'].apply(lambda x:1 if x == 'Poor' else 0)
inf['High_Tech_Limitations'] = inf['Technology Limitations'].apply(lambda x:1 if x == 'High' else 0)

inf['Combined']= inf['Poor_Infrastructure'] * inf['High_Tech_Limitations']
merge = pd.merge(histo, inf, on= 'Date/Time')

corr= merge['Energy Production (kWh)'].corr(merge['Combined'])

# %%
corr
# Out:
# np.float64(-0.015877155348918332)

# %% [markdown]
# EDA (Regulatory Changes and Compliance Cost)

# %%
fig, (ax1, ax2) = plt.subplots(1,2, figsize=(15, 4))

sns.countplot(data=reg, x='Regulatory Changes', ax=ax1, palette= 'viridis')
ax1.set_title('Frequency of Regulatory Changes')
ax1.set_xlabel('Regulatory Changes')
ax1.set_ylabel('Count')

sns.histplot(data=reg, x='Compliance Costs', ax=ax2, bins=30, kde=True, color= 'green')
ax2.set_title('Distribution of Compliance Cost')
ax2.set_xlabel('Compliance Cost')
ax2.set_ylabel('Freq')

plt.tight_layout()
plt.show()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_3592\1348283703.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=reg, x='Regulatory Changes', ax=ax1, palette= 'viridis')

# %% [markdown]
# EDA (Rvenue and Cost)

# %%
histo['Revenue'] = histo['Energy Price'] * histo['Energy Consumption (kWh)']
merge_reg= pd.merge(histo, reg, on= "Date/Time")

merge_reg['Year'] = merge_reg["Date/Time"].dt.year
merge_reg['Month'] = merge_reg["Date/Time"].dt.month

monthly_agg=merge_reg.groupby(['Year', 'Month']).mean(numeric_only=True).reset_index()
monthly_agg['Year-Month']= monthly_agg['Year'].astype(str)+ '-' + monthly_agg['Month'].astype(str)

# %%
#visualize
plt.figure(figsize=(15, 6))

plt.fill_between(monthly_agg['Year-Month'],monthly_agg['Operational Costs'], color='blue', label='Operational Costs',alpha=0.5)
plt.fill_between(monthly_agg['Year-Month'],monthly_agg['Operational Costs'], monthly_agg['Operational Costs'] + monthly_agg['Compliance Costs'], color='yellow', label='Compliance Costs', alpha=0.5)

sns.lineplot(data=monthly_agg, x= 'Year-Month', y='Revenue', label='Revenue', color='red', linewidth=2)

plt.title('Impact of Regulatory changes on Operational, Revenue, and Compliance Costs (Monthly Aggregated)')
plt.xlabel('Date')
plt.ylabel('Amount ($)')
plt.legend(loc= 'upper left')
plt.grid(True, which='both', linestyle='-', linewidth=0.5)
labels= monthly_agg['Year-Month'].tolist()
n= 4
plt.xticks(labels[::n], rotation= 360)

plt.tight_layout()
plt.show()

# %% [markdown]
# EDA (Renewable)

# %%
histo['Year'] = histo["Date/Time"].dt.year
histo['Month'] = histo["Date/Time"].dt.month

monthly_ag = histo.groupby(['Year', 'Month', 'Energy Source']).sum(numeric_only=True)['Energy Production (kWh)'].reset_index()
monthly_ag['Year-Month'] = monthly_ag['Year'].astype(str) + '-' + monthly_ag['Month'].astype(str)

# %%
#viz

plt.figure(figsize=(12, 4))

# Example of plotting (assuming monthly_ag is a DataFrame with the necessary data)
for source in monthly_ag['Energy Source'].unique():
    plt.plot(monthly_ag[monthly_ag['Energy Source'] == source]['Year-Month'], 
             monthly_ag[monthly_ag['Energy Source'] == source]['Energy Production (kWh)'], 
             label=source)

plt.title('Monthly Aggregated Energy Production Trends by Energy Source over Time')
plt.xlabel('Date')
plt.ylabel('Energy Production (kWh)')
plt.legend(title='Energy Source')

plt.grid(True, which='both', linestyle='-', linewidth=0.5)
labels= monthly_ag['Year-Month'].tolist()
n= 4
plt.xticks(labels[::n], rotation= 360)

plt.tight_layout()
plt.show()

# %% [markdown]
# General Insights:
# 1.	Dynamic Energy Landscape: Demand, consumption, and energy production all fluctuate for Energix Enterprise. There are clear times when demand exceeds supply, pointing to possible problems with supply consistency and market stability.
# 2.	Pricing Volatility: Variability in line with more general market price patterns is made possible by their energy pricing. Notably, there is still no correlation between energy consumption and pricing, which could make revenue forecasting and sales predictability difficult.
# 3.	Infrastructure and Technology: The infrastructure and technologies of Energix Enterprise are generally subpar, which prevents it from meeting the growing demand.
# 4.	Regulatory and Financial Implication: With new regulations and changes to interesting ones, they are constantly negotiating a shifting regulatory environment. There are significant financial repercussions in terms of operational and regulatory costs. In contrast, the business is not making a lot of money.
# Emergence of Renewables: As renewables gain traction, the energy market is undergoing a paradigm shift. According to the statistical trend, the generation of renewable energy is surpassing that of fossil fuels.
#
# Resilience Planning and Recommendations
# 1.	Balanced Energy Portfolios: To reduce the risks brought on by variations in production and demand, Energix Enterprise should think about diversifying its energy production portfolio. The energy supply can be stabilized and demand can be met with a well-balanced combination of non-renewable and renewable sources.
# Dynamic Pricing Model: Energix ought to think about putting in place a dynamic pricing model since energy prices and demands are unrelated. Demand, manufacturing costs, and other market variables can all be used by this model to modify prices.
# Infrastructure Revamp: Due to significant technological restrictions and the majority of the company's infrastructure being in "poor" condition. Modernizing their technologies and expanding their infrastructure should be Energix's top priorities.
# 2.	Operational Costs and Regularity Compliance Fund: Because new regulations are introduced on a regular basis, there are related operational and compliance costs. Energix ought to set up a special reserve or fund to cover these unanticipated costs.
# Adopt Renewables: There is no denying the shift toward renewable energy. Energix ought to think about investing more in infrastructure and renewable energy technology. This is not in line with opportunities around the world.
# Cost management and revenue generation: profitability is impacted by operational and compliance costs. To find areas for cost reduction, Energix should conduct a comprehensive analysis of its business processes.
# 3.	Engagement of Stakeholders: To keep ahead of possible regulatory changes, proactively interact with regulatory agencies. This proactive strategy can improve readiness and have a positive impact on regulations for Energix.
# 4.	Consumer insights and market research: To understand customer preferences, particularly with regard to renewable energy, conduct market research on a regular basis. This can direct Energix's price and energy source diversification strategy.
#
# In conclusion, Energix Enterprise operates in a fluctuating energy market with challenges like outdated infrastructure, regulatory pressures, and financial constraints. To address these, the company should diversify its energy portfolio, adopt dynamic pricing, modernize infrastructure, and invest in renewables. Proactive stakeholder engagement and market research will ensure alignment with regulations and consumer preferences. Energix can enhance resilience, efficiency, and market competitiveness by embracing these strategies.
